# %% [markdown]
# # 課題0710
#
# そのまま課題ファイルで編集しないでください。課題ファイルを複製してから課題を回答してください。

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/lvzeyu/css_tohoku/master/css_tohoku/draft/Data/titanic.csv")

# %% [markdown]
# ## 課題1
#
# 以下の図を再現してください
#
# - 年齢の分布を、異なる階級幅を使って、4つのサブプロットをわけて描画する
#    - 階級幅を適当で決めてよい
# - 各サブプロットには、
#     - x軸ラベル、y軸ラベル、サブプロット番号(a-d)を指定する
#     - 水平方向のグリッド線を追加する
#     - ヒストグラムの色を`lightblue`に変更する

# %% [markdown]
# ![](./Figure1.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

fig = plt.figure(figsize=(10, 8))

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

sns.histplot(data=df, x="age", binwidth=2, kde=True, ax=ax1, color="lightblue")
ax1.set_title("a")
ax1.grid(axis="y", linestyle="--", alpha=0.7)  

# サブプロット 2
sns.histplot(data=df, x="age", binwidth=5, kde=True, ax=ax2, color="lightblue")
ax2.set_title("b")
ax2.grid(axis="y", linestyle="--", alpha=0.7) 

# サブプロット 3
sns.histplot(data=df, x="age", binwidth=10, kde=True, ax=ax3, color="lightblue")
ax3.set_title("c")
ax3.grid(axis="y", linestyle="--", alpha=0.7) 

# サブプロット 4
sns.histplot(data=df, x="age", binwidth=20, kde=True, ax=ax4, color="lightblue")
ax4.set_title("d")
ax4.grid(axis="y", linestyle="--", alpha=0.7)  

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 課題2
#
# 以下の図を再現してください
#
# - 男性乗客と女性乗客の年齢の分布をそれぞれ描画する
# - 全乗客の年齢分布を示す灰色ヒストグラムも描画する
# - 図のタイトル、x軸ラベル、y軸ラベル、凡例を設定する

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.figure(figsize=(8, 5))

sns.histplot(
    data=df,
    x="age",
    binwidth=5,
    color="gray",
    alpha=0.3,
    label="All Passengers",
)

sns.histplot(
    data=df[df["sex"] == "male"],
    x="age",
    binwidth=5,
    color="skyblue",
    alpha=0.6,
    label="male",
)

sns.histplot(
    data=df[df["sex"] == "female"],
    x="age",
    binwidth=5,
    color="salmon",
    alpha=0.6,
    label="female",
)

plt.title("Age Distribution of Passengers by Gender", fontsize=14, pad=12)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.legend(title="all passenger in sex", loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ![](./Figure2.png)
